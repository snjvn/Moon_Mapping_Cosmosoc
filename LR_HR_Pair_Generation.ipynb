# %%
import matplotlib.pyplot as plt
import numpy
import os
import numpy as np
import pandas as pd
import bs4

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'astropy trial.ipynb',
#  'ch2_ohr_ncp_20200824T1003365280_d_img_d18.img',
#  'ch2_ohr_ncp_20200824T1003365280_d_img_d18.xml',
#  'ch2_tmc_ncn_20210524T1512098273_d_img_d18.img',
#  'ch2_tmc_ncn_20210524T1512098273_g_grd_d18.csv',
#  'ch2_tmc_ncn_20211111T1322553940_d_img_d18.img',
#  'ch2_tmc_ncn_20211111T1322553940_d_img_d18.xml',
#  'ch2_tmc_ncn_20211111T1322553940_g_grd_d18.csv',
#  'Check_for_Intersection.ipynb',
#  'dir_2019_2020',
#  'dir_2021',
#  'dir_2022',
#  'dot_img_extension.ipynb',
#  'K2_Lightcurve.ipynb',
#  'LR_HR_Pair_Generation.ipynb',
#  'tmc_data',
#  'tmc_img_access_using_csv_pixels.ipynb']

# %%
with open('ch2_ohr_ncp_20200824T1003365280_d_img_d18.xml', 'r') as xml_file:
    contents = xml_file.read()

soup = bs4.BeautifulSoup(contents, 'lxml')

# %%
lat = np.zeros((2, 2))
lon = np.zeros((2, 2))

# %%
lat[0, 0] = float(soup.find_all('isda:upper_left_latitude')[1].text)
lat[0, 1] = float(soup.find_all('isda:upper_right_latitude')[1].text)
lat[1, 0] = float(soup.find_all('isda:lower_left_latitude')[1].text)
lat[1, 1] = float(soup.find_all('isda:lower_right_latitude')[1].text)
lat
# Out:
# array([[-61.660467, -61.657424],
#        [-62.490045, -62.486906]])

# %%
lon[0, 0] = float(soup.find_all('isda:upper_left_longitude')[1].text)
lon[0, 1] = float(soup.find_all('isda:upper_right_longitude')[1].text)
lon[1, 0] = float(soup.find_all('isda:lower_left_longitude')[1].text)
lon[1, 1] = float(soup.find_all('isda:lower_right_longitude')[1].text)
lon
# Out:
# array([[56.577047, 56.807375],
#        [56.666465, 56.902936]])

# %%
csv = 'ch2_tmc_ncn_20210524T1512098273_g_grd_d18.csv'

# %%
df = pd.read_csv(csv)
df['ul_lon_difference'] = df['Longitude'] - lon[0, 0]
df['ur_lon_difference'] = df['Longitude'] - lon[0, 1]
df['ll_lon_difference'] = df['Longitude'] - lon[1, 0]
df['lr_lon_difference'] = df['Longitude'] - lon[1, 1]

df['ul_lat_difference'] = df['Latitude'] - lat[0, 0]
df['ur_lat_difference'] = df['Latitude'] - lat[0, 1]
df['ll_lat_difference'] = df['Latitude'] - lat[1, 0]
df['lr_lat_difference'] = df['Latitude'] - lat[1, 1]

# %%
df
# Out:
#        Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 0      51.969681 -57.228175      0       0          -4.607366
# 1      52.007449 -57.227728    100       0          -4.569598
# 2      52.045212 -57.227268    200       0          -4.531835
# 3      52.082971 -57.226796    300       0          -4.494076
# 4      52.120725 -57.226311    400       0          -4.456322
# ...          ...        ...    ...     ...                ...
# 72401  65.410303 -85.811262   3600  176475           8.833255
# 72402  65.654459 -85.806563   3700  176475           9.077412
# 72403  65.898085 -85.801786   3800  176475           9.321038
# 72404  66.141175 -85.796933   3900  176475           9.564128
# 72405  66.381300 -85.792052   3999  176475           9.804253
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 0              -4.837694          -4.696784          -4.933255
# 1              -4.799926          -4.659016          -4.895487
# 2              -4.762163          -4.621253          -4.857724
# 3              -4.724404          -4.583494          -4.819965
# 4              -4.686650          -4.545740          -4.782211
# ...                  ...                ...                ...
# 72401           8.602927           8.743837           8.507367
# 72402           8.847084           8.987994           8.751523
# 72403           9.090710           9.231620           8.995149
# 72404           9.333800           9.474710           9.238239
# 72405           9.573925           9.714835           9.478364
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 0               4.432292           4.429249           5.261870
# 1               4.432739           4.429696           5.262317
# 2               4.433199           4.430156           5.262777
# 3               4.433671           4.430628           5.263249
# 4               4.434156           4.431113           5.263734
# ...                  ...                ...                ...
# 72401         -24.150795         -24.153838         -23.321217
# 72402         -24.146096         -24.149139         -23.316518
# 72403         -24.141319         -24.144362         -23.311741
# 72404         -24.136466         -24.139509         -23.306888
# 72405         -24.131585         -24.134628         -23.302007
#
#        lr_lat_difference
# 0               5.258731
# 1               5.259178
# 2               5.259638
# 3               5.260110
# 4               5.260595
# ...                  ...
# 72401         -23.324356
# 72402         -23.319657
# 72403         -23.314880
# 72404         -23.310027
# 72405         -23.305146
#
# [72406 rows x 12 columns]

# %%
ul_lon_df = df[abs(df['ul_lon_difference']) < 0.1]
ur_lon_df = df[abs(df['ur_lon_difference']) < 0.1]
ll_lon_df = df[abs(df['ll_lon_difference']) < 0.1]
lr_lon_df = df[abs(df['lr_lon_difference']) < 0.1]

ul_lat_df = df[abs(df['ul_lat_difference']) < 0.1]
ur_lat_df = df[abs(df['ur_lat_difference']) < 0.1]
ll_lat_df = df[abs(df['ll_lat_difference']) < 0.1]
lr_lat_df = df[abs(df['lr_lat_difference']) < 0.1]

# %%
df[abs(df['ur_lon_difference']) == min(abs(df['ur_lon_difference']))]
# Out:
#        Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 59437  56.807558 -80.731561   2800  144900           0.230511
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 59437           0.000183           0.141093          -0.095378
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 59437         -19.071094         -19.074137         -18.241516
#
#        lr_lat_difference
# 59437         -18.244655

# %%
df[abs(df['ll_lon_difference']) == min(abs(df['ll_lon_difference']))]
# Out:
#        Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 54566  56.666455 -78.780485   3600  133000           0.089408
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 54566           -0.14092           -0.00001          -0.236481
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 54566         -17.120018         -17.123061          -16.29044
#
#        lr_lat_difference
# 54566         -16.293579

# %%
df[abs(df['ur_lat_difference']) == min(abs(df['ur_lat_difference']))]
# Out:
#        Longitude   Latitude  Pixel   Scan  ul_lon_difference  \
# 11244  52.493962 -61.657463   1000  27400          -4.083085
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 11244          -4.313413          -4.172503          -4.408974
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 11244           0.003004          -0.000039           0.832583
#
#        lr_lat_difference
# 11244           0.829443

# %%
df[abs(df['ll_lat_difference']) == min(abs(df['ll_lat_difference']))]
# Out:
#        Longitude   Latitude  Pixel   Scan  ul_lon_difference  \
# 13390  53.135629 -62.489889   2400  32600          -3.441418
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 13390          -3.671746          -3.530836          -3.767307
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 13390          -0.829422          -0.832465           0.000156
#
#        lr_lat_difference
# 13390          -0.002983

# %% [markdown]
# another

# %%
csv = 'ch2_tmc_ncn_20211111T1322553940_g_grd_d18.csv'

# %%
df = pd.read_csv(csv)
df['ul_lon_difference'] = df['Longitude'] - lon[0, 0]
df['ur_lon_difference'] = df['Longitude'] - lon[0, 1]
df['ll_lon_difference'] = df['Longitude'] - lon[1, 0]
df['lr_lon_difference'] = df['Longitude'] - lon[1, 1]

df['ul_lat_difference'] = df['Latitude'] - lat[0, 0]
df['ur_lat_difference'] = df['Latitude'] - lat[0, 1]
df['ll_lat_difference'] = df['Latitude'] - lat[1, 0]
df['lr_lat_difference'] = df['Latitude'] - lat[1, 1]

# %%
df
# Out:
#         Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 0      329.816921 -87.688668      0       0         273.239874
# 1      329.396545 -87.692025    100       0         272.819498
# 2      328.975003 -87.695257    200       0         272.397956
# 3      328.552333 -87.698364    300       0         271.975286
# 4      328.128576 -87.701346    400       0         271.551529
# ...           ...        ...    ...     ...                ...
# 78264  138.709781 -60.803640   3600  190795          82.132734
# 78265  138.743477 -60.803544   3700  190795          82.166430
# 78266  138.777175 -60.803439   3800  190795          82.200128
# 78267  138.810876 -60.803326   3900  190795          82.233829
# 78268  138.844242 -60.803206   3999  190795          82.267195
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 0             273.009546         273.150456         272.913985
# 1             272.589170         272.730080         272.493609
# 2             272.167628         272.308538         272.072067
# 3             271.744958         271.885868         271.649397
# 4             271.321201         271.462111         271.225640
# ...                  ...                ...                ...
# 78264          81.902406          82.043316          81.806845
# 78265          81.936102          82.077012          81.840541
# 78266          81.969800          82.110710          81.874239
# 78267          82.003501          82.144411          81.907940
# 78268          82.036867          82.177777          81.941306
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 0             -26.028201         -26.031244         -25.198623
# 1             -26.031558         -26.034601         -25.201980
# 2             -26.034790         -26.037833         -25.205212
# 3             -26.037897         -26.040940         -25.208319
# 4             -26.040879         -26.043922         -25.211301
# ...                  ...                ...                ...
# 78264           0.856827           0.853784           1.686405
# 78265           0.856923           0.853880           1.686501
# 78266           0.857028           0.853985           1.686606
# 78267           0.857140           0.854098           1.686719
# 78268           0.857261           0.854218           1.686839
#
#        lr_lat_difference
# 0             -25.201762
# 1             -25.205119
# 2             -25.208351
# 3             -25.211458
# 4             -25.214440
# ...                  ...
# 78264           1.683266
# 78265           1.683362
# 78266           1.683467
# 78267           1.683580
# 78268           1.683700
#
# [78269 rows x 12 columns]

# %%
df[abs(df['ul_lon_difference']) == min(abs(df['ul_lon_difference']))]
# Out:
#       Longitude   Latitude  Pixel   Scan  ul_lon_difference  \
# 5786  56.618701 -89.628627    500  14100           0.041654
#
#       ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 5786          -0.188674          -0.047764          -0.284235
#
#       ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 5786          -27.96816         -27.971203         -27.138582
#
#       lr_lat_difference
# 5786         -27.141721

# %%
df[abs(df['lr_lon_difference']) == min(abs(df['lr_lon_difference']))]
# Out:
#       Longitude   Latitude  Pixel   Scan  ul_lon_difference  \
# 5752   56.84926 -89.750058   1200  14000           0.272213
#
#       ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 5752           0.041885           0.182795          -0.053676
#
#       ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 5752         -28.089591         -28.092634         -27.260013
#
#       lr_lat_difference
# 5752         -27.263152

# %%
df[abs(df['ul_lat_difference']) == min(abs(df['ul_lat_difference']))]
# Out:
#        Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 76098  137.54282 -61.660547    200  185600          80.965773
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 76098          80.735445          80.876355          80.639884
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 76098           -0.00008          -0.003123           0.829498
#
#        lr_lat_difference
# 76098           0.826359

# %%
df[abs(df['lr_lat_difference']) == min(abs(df['lr_lat_difference']))]
# Out:
#         Longitude   Latitude  Pixel    Scan  ul_lon_difference  \
# 74048  137.520249 -62.486887    200  180600          80.943202
#
#        ur_lon_difference  ll_lon_difference  lr_lon_difference  \
# 74048          80.712874          80.853784          80.617313
#
#        ul_lat_difference  ur_lat_difference  ll_lat_difference  \
# 74048           -0.82642          -0.829463           0.003158
#
#        lr_lat_difference
# 74048           0.000019
